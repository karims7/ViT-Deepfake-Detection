# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `Deepfake Borealis` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `Deepfake Borealis`

# %%
# Install Required Libraries:

# !pip install -q \
  torch torchvision \
  transformers==4.50.3 \
  datasets==3.5.0 \
  evaluate==0.4.3 \
  matplotlib \
  pillow==11.1.0

# %%
# 2. Imports and Setup

from PIL import Image
from pathlib import Path
import random
import torch
import numpy as np
import evaluate
import logging
import matplotlib.pyplot as plt
from datasets import Dataset, DatasetDict
from transformers import (
    ViTImageProcessor,
    ViTForImageClassification,
    TrainingArguments,
    Trainer
)

from google.colab import drive, files
import os

# Enable logging
logging.basicConfig(
    filename="training_log.txt",
    filemode='w',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# %%
# 3. Download & Unzip Dataset

# !pip install -q gdown

import gdown
import zipfile

# Download from Google Drive
file_id = "1Agtz0ArwKCzGRkc4htaa2tTrz8mLr-cf"
gdown.download(f"https://drive.google.com/uc?id={file_id}", output="datasetTWO.zip", quiet=False)

# Unzip dataset
with zipfile.ZipFile("datasetTWO.zip", 'r') as zip_ref:
    zip_ref.extractall("datasetTWO")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Agtz0ArwKCzGRkc4htaa2tTrz8mLr-cf
# From (redirected): https://drive.google.com/uc?id=1Agtz0ArwKCzGRkc4htaa2tTrz8mLr-cf&confirm=t&uuid=0dd2c61e-17f4-4252-a71e-46a4a09b5dea
# To: /content/datasetTWO.zip
# 100%|██████████| 59.3M/59.3M [00:00<00:00, 88.7MB/s]

# %%
# 4. Load Dataset

from pathlib import Path
from PIL import Image
import random

def load_dataset_split(split_folder, max_per_class=200):
    data = []
    for label_name, label in [("real", 0), ("fake", 1)]:
        folder_path = Path(split_folder) / label_name
        image_paths = list(folder_path.rglob("*"))
        image_paths = [p for p in image_paths if p.suffix.lower() in [".jpg", ".jpeg", ".png", ".bmp", ".webp"]]
        # !ls
        print(image_paths)
        selected_paths = random.sample(image_paths, min(max_per_class, len(image_paths)))

        for p in selected_paths:
            try:
                img = Image.open(p).convert("RGB")
                data.append({"image": img, "label": label})
            except Exception as e:
                print(f"Could not load image {p}: {e}")
    return data

train_data = load_dataset_split("datasetTWO/OpenForensics/train", max_per_class=2100)
val_data   = load_dataset_split("datasetTWO/OpenForensics/valid", max_per_class=450)
test_data  = load_dataset_split("datasetTWO/OpenForensics/test", max_per_class=450)

from datasets import Dataset, DatasetDict

dataset = DatasetDict({
    "train": Dataset.from_list(train_data),
    "validation": Dataset.from_list(val_data),
    "test": Dataset.from_list(test_data),
})
# Out:
# datasetTWO  datasetTWO.zip  sample_data
# [PosixPath('datasetTWO/OpenForensics/train/real/real_47706.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_6106.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_57171.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_62607.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_41913.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_13411.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_17135.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_6898.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_376.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_581.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_60976.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_16728.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_17978.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_3483.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_7086.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_19605.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_6608.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_50202.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_23795.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_52162.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_68938.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_19288.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_5028.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_67203.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_57097.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_10209.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_10168.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_65742.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_55797.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_55126.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_16071.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_59217.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_7478.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_20636.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_4882.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_6732.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_11410.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_29478.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real_23384.jpg'), PosixPath('datasetTWO/OpenForensics/train/real/real
jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_13830.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_49864.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_28471.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_1546.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_19010.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_42430.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_14440.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_64292.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_53243.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_19563.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_68138.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_15540.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_60829.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_65249.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_10595.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_25715.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_44677.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_26397.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_39431.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_61469.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_63918.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_87.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_15917.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real_45820.jpg'), PosixPath('datasetTWO/OpenForensics/test/real/real ...
# datasetTWO  datasetTWO.zip  sample_data
# [PosixPath('datasetTWO/OpenForensics/test/fake/fake_41238.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_28548.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_31714.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_57266.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_4414.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_42233.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_1572.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_12613.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_33224.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_142.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_55567.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_23423.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_19180.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_3054.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_12777.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_48327.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_34689.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_17860.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_4813.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_34484.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_11511.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_43517.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_984.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_51777.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_62910.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_56703.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_34583.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_12810.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_26680.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_66134.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_65761.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_20364.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_2552_1.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_4585.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_17605.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_739.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_22211.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_4895.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_46322.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_4177.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_67149.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_16707.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_3525.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_8955.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_15389.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_9959.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_1931.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_8495.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_54447.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_69886.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_51389.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_11776.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_9228.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_6472.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_2577.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_10718.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_48475.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_8246.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_51461.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_52408.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_15066.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_46934.jpg'), PosixPath('datasetTWO/OpenForensics/test/fake/fake_2 ...

# %%
from transformers import ViTImageProcessor, ViTForImageClassification, TrainingArguments, Trainer
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import torch
import numpy as np

# 5. Prepare Model & Trainer

image_processor = ViTImageProcessor.from_pretrained("google/vit-base-patch16-224-in21k")

def transform(example_batch):
    inputs = image_processor([img for img in example_batch["image"]], return_tensors="pt")
    inputs["labels"] = example_batch["label"]
    return inputs

dataset["train"] = dataset["train"].with_transform(transform)
dataset["validation"] = dataset["validation"].with_transform(transform)

def collate_fn(batch):
    return {
        "pixel_values": torch.stack([x["pixel_values"] for x in batch]),
        "labels": torch.tensor([x["labels"] for x in batch])
    }

model = ViTForImageClassification.from_pretrained(
    "google/vit-base-patch16-224-in21k",
    num_labels=2,
    id2label={"0": "real", "1": "fake"},
    label2id={"real": 0, "fake": 1}
)

# Improved hyperparameters
training_args = TrainingArguments(
    output_dir="./vit-my-winning-run",
    per_device_train_batch_size=24,
    gradient_accumulation_steps=1,
    fp16=True,
    num_train_epochs=10,
    learning_rate=3e-5,
    weight_decay=0.02,
    warmup_ratio=0.08,
    lr_scheduler_type="cosine",
    label_smoothing_factor=0.05,
    logging_steps=10,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=2,
    remove_unused_columns=False,
    report_to="none",
    load_best_model_at_end=True,
    metric_for_best_model="eval_f1",
    greater_is_better=True
)



# returns F1 and others
def compute_metrics(p):
    preds = np.argmax(p.predictions, axis=1)
    labels = p.label_ids
    return {
        "accuracy": accuracy_score(labels, preds),
        "f1": f1_score(labels, preds, average="weighted"),
        "precision": precision_score(labels, preds, average="weighted"),
        "recall": recall_score(labels, preds, average="weighted")
    }

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    tokenizer=image_processor,
    data_collator=collate_fn,
    compute_metrics=compute_metrics
)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1611: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# <ipython-input-18-dd8cc45bd155>:67: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
import torch

if torch.cuda.is_available():
    print("GPU is active:", torch.cuda.get_device_name(0))
else:
    print("GPU not available — double check runtime settings.")
# Out:
# GPU is active: Tesla T4

# %%
# 6. Train & Save Model

trainer.train()

model.save_pretrained("./vit-deepfake-finetune/best_model")
image_processor.save_pretrained("./vit-deepfake-finetune/best_model")
# Out:
#     <div>
#
#       <progress value='1750' max='1750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1750/1750 13:53, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.225900</td>
#       <td>0.256723</td>
#       <td>0.928889</td>
#       <td>0.928810</td>
#       <td>0.930804</td>
#       <td>0.928889</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.200200</td>
#       <td>0.235995</td>
#       <td>0.934444</td>
#       <td>0.934321</td>
#       <td>0.937732</td>
#       <td>0.934444</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.138800</td>
#       <td>0.192458</td>
#       <td>0.961111</td>
#       <td>0.961111</td>
#       <td>0.961113</td>
#       <td>0.961111</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.132200</td>
#       <td>0.216073</td>
#       <td>0.956667</td>
#       <td>0.956655</td>
#       <td>0.957175</td>
#       <td>0.956667</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.118200</td>
#       <td>0.220785</td>
#       <td>0.962222</td>
#       <td>0.962207</td>
#       <td>0.962963</td>
#       <td>0.962222</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.117100</td>
#       <td>0.214170</td>
#       <td>0.956667</td>
#       <td>0.956664</td>
#       <td>0.956777</td>
#       <td>0.956667</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.117100</td>
#       <td>0.213386</td>
#       <td>0.958889</td>
#       <td>0.958889</td>
#       <td>0.958891</td>
#       <td>0.958889</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.117000</td>
#       <td>0.213504</td>
#       <td>0.957778</td>
#       <td>0.957778</td>
#       <td>0.957787</td>
#       <td>0.957778</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.117000</td>
#       <td>0.213619</td>
#       <td>0.957778</td>
#       <td>0.957778</td>
#       <td>0.957787</td>
#       <td>0.957778</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.117000</td>
#       <td>0.213570</td>
#       <td>0.957778</td>
#       <td>0.957778</td>
#       <td>0.957787</td>
#       <td>0.957778</td>
#     </tr>
#   </tbody>
# </table><p>
# ['./vit-deepfake-finetune/best_model/preprocessor_config.json']

# %%
# 7. Evaluate on Test Set

dataset["test"] = dataset["test"].with_transform(transform)
metrics = trainer.evaluate(eval_dataset=dataset["test"])
test_acc = metrics["eval_accuracy"]

logging.info(f"Test Set Accuracy: {test_acc:.4f}")
logging.info("=== Training Complete ===")
print("Test Set Accuracy:", test_acc)
# Out:
#     <div>
#
#       <progress value='113' max='113' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [113/113 00:10]
#     </div>
# Test Set Accuracy: 0.9655555555555555

# %%
# 8. Plot Loss Curve

train_loss = [log["loss"] for log in trainer.state.log_history if "loss" in log]
eval_loss = [log["eval_loss"] for log in trainer.state.log_history if "eval_loss" in log]
steps_train = [log["step"] for log in trainer.state.log_history if "loss" in log]
steps_eval = [log["step"] for log in trainer.state.log_history if "eval_loss" in log]

plt.figure(figsize=(10, 6))
plt.plot(steps_train, train_loss, label="Training Loss")
plt.plot(steps_eval, eval_loss, label="Validation Loss")
plt.xlabel("Training Steps")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("loss_curve.png")
plt.show()
